# %%
import pandas as pd
import warnings

# %%
data_songs=pd.read_csv('datasets/data_songs.csv').set_index('id', drop=True)

# %%
data_songs
# Out:
#                         Unnamed: 0  danceability  energy  key  loudness  mode  \
# id
# 40ooZvE9wvUQ8oNfSzs73N           0         0.537   0.249  8.0   -15.097   1.0
# 2uodmGkOcpgzObLo1cdSPh           1         0.903   0.511  1.0   -10.974   1.0
# 7w9UoMZ5Jk22dFdNHi7pBU           2         0.697   0.268  0.0   -12.495   1.0
# 1algWk375QvT1XNJJbRsGM           3         0.824   0.377  1.0    -8.859   0.0
# 2CdTLdDjwZdVcm0bresVWx           4         0.503   0.548  0.0    -7.564   0.0
# ...                            ...           ...     ...  ...       ...   ...
# 65qTDCHsyf7MTocHnvkKsd       15800         0.449   0.807  5.0    -4.984   1.0
# 46Nr71GAHoSO5aqtUMUXT6       15801         0.436   0.822  4.0    -3.325   0.0
# 7nhHhAK4luQGM6yxIAZcF4       15802         0.340   0.721  7.0    -7.748   1.0
# 6wVjWIoAuJUqizw5MdgzDf       15803         0.524   0.680  8.0    -5.259   1.0
# 5ytqjKYVYjVcA03MTBArnY       15804         0.511   0.947  9.0    -4.652   1.0
#
# ...

# %%
data_songs['error'].unique()
# Out:
# array([nan, "{'status': 429, 'message': 'API rate limit exceeded'}",
#        "{'status': 404, 'message': 'analysis not found'}"], dtype=object)

# %%
data_songs = data_songs[data_songs['error'].isnull()]
data_songs.drop(['Unnamed: 0','type','uri','track_href','analysis_url','duration_ms','error'], axis = 'columns', inplace=True)
# Out:
# /Users/albertofernandez/miniconda3/envs/proj_final/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
data_songs.isnull().sum()
# Out:
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# dtype: int64

# %%
data_songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14486 entries, 40ooZvE9wvUQ8oNfSzs73N to 5ytqjKYVYjVcA03MTBArnY
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      14486 non-null  float64
#  1   energy            14486 non-null  float64
#  2   key               14486 non-null  float64
#  3   loudness          14486 non-null  float64
#  4   mode              14486 non-null  float64
#  5   speechiness       14486 non-null  float64
#  6   acousticness      14486 non-null  float64
#  7   instrumentalness  14486 non-null  float64
#  8   liveness          14486 non-null  float64
#  9   valence           14486 non-null  float64
#  10  tempo             14486 non-null  float64
#  11  time_signature    14486 non-null  float64
# dtypes: float64(12)
# memory usage: 1.4+ MB

# %%
data_songs.drop_duplicates(['danceability', 'energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo','time_signature'], keep='last', inplace=True)
# Out:
# /Users/albertofernandez/miniconda3/envs/proj_final/lib/python3.7/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
data_songs.to_csv('datasets/data_songs_clean.csv')
